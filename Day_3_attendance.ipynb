# %% [markdown]
# <a href="https://colab.research.google.com/github/pravensvg63-dev/Hospital-Patient-Data-Analysis/blob/main/Day_3_attendance.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def attendance(attended, total):
    return (attended / total) * 100

attended = int(input("classes Attended: "))
total  = int(input("Total classes: "))

percent  = attendance(attended, total)

print("Attendance percentage =", round(percent, 2),"%")
# Out:
# classes Attended: 55
# Total classes: 40
# Attendance percentage = 137.5 %
