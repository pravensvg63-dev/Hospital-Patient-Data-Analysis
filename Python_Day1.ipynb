# %% [markdown]
# <a href="https://colab.research.google.com/github/pravensvg63-dev/Hospital-Patient-Data-Analysis/blob/main/Python_Day1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("welcome to Python with Data Analysis class")
# Out:
# welcome to Python with Data Analysis class
